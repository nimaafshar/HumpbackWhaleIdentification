# %%
import cv2 as cv
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import matplotlib.cm as cmap

# %%
gray = cv.imread('./train/8004878e4.jpg',cv.IMREAD_GRAYSCALE)

# %%
color = cv.imread('./train/8004878e4.jpg')

# %%
plt.imshow(gray,cmap=cmap.gray)

# %%
plt.imshow(color)

# %%
km = KMeans(n_clusters=3)
# km.fit()
